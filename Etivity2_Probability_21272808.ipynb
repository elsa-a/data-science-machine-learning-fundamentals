# %% [markdown]
# ### Your details

# %% [markdown]
# Your Name: Elsa Anza Martín

# %% [markdown]
# Your ID number: 21272808

# %% [markdown]
# # Task 1
#
# ## Probability Distribution
#
# (Describe the task)

# %% [markdown]
# ## Approach
#
# In this Etivity's task I've designed two random experiments that provide examples of normal and uniform distributions, as well as continuous and discrete type of variables. Random data is produced using numpy's random library for both cases.
# In the case of the uniform distribution, a loop is used to fill in a list with random values.
# For the normal distribution a list is generated by using the numpy module random.normal.
# Values for the mean and the std are computed separatedly using numpy aswell, which is the most convinient approach since we have our values stored in lists.

# %% [markdown]
# ## Manual Calculations
#
# (Provide details of the manual calculations)

# %% [markdown]
# ###Approximate the following:
# #### The expected value of your random variable.
#
#   This is reflected in the 'mean' variable and is printed below the graph.
# #### The standard deviation of your random variable.
#
# This is reflected in the 'std' variable and is printed below the graph.

# %%
# Your code
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Experiment 1 - Uniform Distribution
#
# The following code simulates samples from a rolling dice experiment.
# Variables are discrete.

# %%
RANDOM_SEED = 42
random.seed(RANDOM_SEED)

sample_size =10000

dices = list(range(sample_size)) #create an empty list

for i in range(sample_size): #fill the list with randomly generated integers with values ranging 1 to 6.
  dices[i] = random.randint(1,6)

# %% [markdown]
# ### Histogram for the uniform distribution
# The following code uses the data generated in the previous cell and plots it into a histogram showing the frequency of each possible result.

# %%
n_bins = 6
# Generate an uniform distribution with data in 'dices'
plt.xlabel('Dice result')
plt.ylabel('Frecuency')
plt.title('Histogram of a Rolling Dice Experiment (Uniform Distribution)')
plt.hist(dices, bins=n_bins, align='mid', color='powderblue') # Plot is centered in the middle, with 'n_bins'
# Out:
# (array([1618., 1629., 1647., 1687., 1671., 1748.]),
#  array([1.        , 1.83333333, 2.66666667, 3.5       , 4.33333333,
#         5.16666667, 6.        ]),
#  <a list of 6 Patch objects>)

# %% [markdown]
# ### Results for Experiment 1

# %%
mean = np.mean(dices) #mean 
std = np.std(dices) #standard deviation 

print("NORMAL DISTRIBUTION\n\nMean:", mean)

print("\nStandard Deviation:", std, "\n")
# Out:
# NORMAL DISTRIBUTION
#
# Mean: 3.5408
#
# Standard Deviation: 1.7111210827992274

# %% [markdown]
# ## Experiment 2: Normal distribution
#
# The following code simulates samples from scores achieved by students in a given module. Average grading results are out of 100 and the variables in this case are continous.

# %%
normal_data = np.random.normal(loc=75, scale=6.2, size=2000) #loc = mean, scale = std, size = # samples
normal_data[0:20] #print 20 first generated values
# Out:
# array([78.38737833, 72.84094195, 76.72732384, 83.87723626, 75.41370892,
#        76.66564844, 79.42636785, 79.2901682 , 83.32410114, 66.3976074 ,
#        72.42013848, 69.19011063, 89.38224194, 78.33799976, 80.14036696,
#        70.3631326 , 76.26008348, 82.25368888, 76.97403259, 68.45004915])

# %%
plt.xlabel('Grades (out of 100)')
plt.ylabel('Frequency')
plt.title('Histogram of Average Grades obtained by students (Normal Distribution)')
plt.hist(normal_data, bins=10, align='mid', rwidth=1, color='powderblue')
# Out:
# (array([ 11.,  59., 127., 341., 454., 487., 316., 146.,  45.,  14.]),
#  array([55.10695956, 59.08705434, 63.06714911, 67.04724389, 71.02733866,
#         75.00743344, 78.98752821, 82.96762299, 86.94771776, 90.92781254,
#         94.90790731]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Results for Experiment 2

# %%
mean = np.mean(normal_data) #mean
std = np.std(normal_data) #standard deviation
print("NORMAL DISTRIBUTION\n\nMean:", mean)
print("\nStandard Deviation:", std, "\n")
# Out:
# NORMAL DISTRIBUTION
#
# Mean: 74.98000929467234
#
# Standard Deviation: 6.298785001980067
